# %%
# import sys
# !{sys.executable} -m pip uninstall splinter -y
# !{sys.executable} -m pip install splinter==0.18.0 selenium
# !{sys.executable} -m pip install webdriver_manager

# %%
# Import BeautifulSoup
#pip install beautifulsoup4
# pip install imbalanced-learn==0.9.0
# pip install scikit-learn==1.0
from bs4 import BeautifulSoup
import pandas as pd
from splinter import Browser
import time
from webdriver_manager.chrome import ChromeDriverManager

# %%
url = ' https://redplanetscience.com/'
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
browser.visit(url)
time.sleep(2)

html = browser.html

soup = BeautifulSoup(html, 'html.parser')

news = []


titles = soup.find_all('div', class_="content_title")

teaser = soup.find_all('div', class_='article_teaser_body')

for title in titles:
    dict_news = {}
    print ("Title: "+title.text)
    dict_news['Title'] = title.text
    for tease in teaser:
        print ("Teaser: "+tease.text)
        dict_news["Teaser"] = tease.text
        news.append(dict_news)
# Out:
# Title: How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: NASA's Mars 2020 Rover Closer to Getting Its Name
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: Naming a NASA Mars Rover Can Change Your Life
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: Mars Scientists Investigate Ancient Life in Australia
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: MOXIE Could Help Future Rockets Launch Off Mars
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: NASA-JPL Names 'Rolling Stones Rock' on Mars
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: 7 Things to Know About the Mars 2020 Perseverance Rover Mission
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: NASA's Mars Helicopter Attached to Mars 2020 Rover
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: NASA's Curiosity Rover Finds an Ancient Oasis on Mars
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: What's Mars Solar Conjunction, and Why Does It Matter?
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: NASA Invites Public to Share Excitement of Mars 2020 Perseverance Rover Launch
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.
# Title: Curiosity Mars Rover's Summer Road Trip Has Begun
# Teaser: Like much of the rest of the world, the Mars rover team is pushing forward with its mission-critical work while putting the health and safety of their colleagues and community first.
# Teaser: 155 students from across the U.S. have been chosen as semifinalists in NASA's essay contest to name the Mars 2020 rover, and see it launch from Cape Canaveral this July.
# Teaser: For the first time in the history of space exploration, scientists have measured the seasonal changes in the gases that fill the air directly above the surface of Gale Crater on Mars.
# Teaser: Want to name the robotic scientist NASA is sending to Mars in 2020? The student who named Curiosity — the rover currently exploring Mars — will tell you this is an opportunity worth taking.
# Teaser: Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions.
# Teaser: Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.
# Teaser: NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel.
# Teaser: The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan.
# Teaser: NASA's Mars InSight mission honored one of the biggest bands of all time at Pasadena concert.
# Teaser: NASA's next rover to the Red Planet is slated to launch no earlier than July 30. These highlights will get you up to speed on the ambitious mission.
# Teaser: The helicopter will be first aircraft to perform flight tests on another planet.
# Teaser: New evidence suggests salty, shallow ponds once dotted a Martian crater — a sign of the planet's drying climate.
# Teaser: NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.
# Teaser: There are lots of ways to participate in the historic event, which is targeted for July 30.
# Teaser: After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.

# %%
news
# Out:
# [{'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "How NASA's Perseverance Mars Team Adjusted to Work in the Time of Coronavirus ",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "NASA's Mars 2020 Rover Closer to Getting Its Name",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Naming a NASA Mars Rover Can Change Your Life',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes",
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'MOXIE Could Help Future Rockets Launch Off Mars',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'MOXIE Could Help Future Rockets Launch Off Mars',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 'MOXIE Could Help Future Rockets Launch Off Mars',
#   'Teaser': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'Title': 